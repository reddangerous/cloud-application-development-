# %% [markdown]
# <a href="https://www.kaggle.com/code/davidkinyanjui/intro-to-cloud-development?scriptVersionId=108063884" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# **loops in python**

# %%
for x in range(6):
    print(x)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# If else Statement

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a")
elif a ==b:
    print(" a is equal to b")
else:
    print("a is greater than b")
# Out:
# a is greater than b

# %% [markdown]
# **While loop statement**

# %%
i = 0
while i <5:
    i+=1
    if i == 3:
        continue
        print(i)

# %%
import random
print(random.randint(0,9))
# Out:
# 4

# %%
import random
num = random.random()
print(num)
# Out:
# 0.08839326660294622

# %%
num = random.randint(0,10000)
arr = []
while num !=2317:
    arr.append(num)
    num = random.randint(0,10000)
    
print(num)
print(" took :",len(arr)," to generate the number" )
# Out:
# 2317
#  took : 3872  to generate the number

# %% [markdown]
# Random
